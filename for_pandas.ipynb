# %%
import script_by_post_request
from script_by_post_request import df

# %%
df.index
# Out:
# RangeIndex(start=0, stop=435, step=1)

# %%
df.columns
# Out:
# Index(['ac', 'ac_scale', 'ac_scale_number', 'alignment', 'attack_bonus',
#        'attack_bonus_scale', 'attack_bonus_scale_number', 'category',
#        'charisma', 'charisma_scale',
#        ...
#        'item', 'stealth', 'legacy_id', 'spell_attack_bonus',
#        'spell_attack_bonus_scale', 'spell_attack_bonus_scale_number',
#        'element', 'legacy_name', 'hardness', 'hardness_raw'],
#       dtype='object', length=119)

# %%
df[['name', 'url', 'source']]
# Out:
#                      name                     url  \
# 0               Bee Borer  /Monsters.aspx?ID=3956
# 1        Beiran Frosthunt  /Monsters.aspx?ID=3809
# 2                 Binumir   /Monsters.aspx?ID=985
# 3              Black Bear   /Monsters.aspx?ID=566
# 4    Blacknoon Apprentice  /Monsters.aspx?ID=2612
# ..                    ...                     ...
# 430    Zoudou the Zealous  /Monsters.aspx?ID=2734
# 431               Zrukbat   /Monsters.aspx?ID=988
# 432              Zuipnyrn   /Monsters.aspx?ID=515
# 433                Zungur      /NPCs.aspx?ID=4009
# 434      Zyss Serpentfolk  /Monsters.aspx?ID=3181
#
#                                                 source
# 0    [Pathfinder #217: Death Sails a Wine-Dark Sea\...
# 1                                   [Shining Kingdoms]
# 2      [Pathfinder #157: Devil at the Dreaming Palace]
# 3                                         [Bestiary 2]
# 4                    [Pathfinder #193: Mantle of Gold]
# ...

# %%
df.iloc[10]
# Out:
# ac                                       16
# ac_scale                           Moderate
# ac_scale_number                           3
# alignment                                 N
# attack_bonus                           [11]
#                                      ...
# spell_attack_bonus_scale_number         NaN
# element                                 NaN
# legacy_name                             NaN
# hardness                                NaN
# hardness_raw                            NaN
# Name: 10, Length: 119, dtype: object

# %%
df['ac_scale'].value_counts()
# Out:
# ac_scale
# Moderate    218
# High        206
# Low           8
# Extreme       3
# Name: count, dtype: int64

# %%
df[df['ac_scale']=='Extreme']['name']
# Out:
# 105     Fading Fox
# 240    Mister Beak
# 287      Quickling
# Name: name, dtype: object
